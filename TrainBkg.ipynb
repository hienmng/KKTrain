# %% [markdown]
# # Hit classification

# %% [markdown]
# Set initial variables for the "suffix" identifier for the data set and "filePath" the relative path to the data files. Remember to add "/" to the end of your path, for example "../../TrkAna/43291981/"

# %%
# import os

# suffix = "TTtpr"
# treename = "TAtpr"
# file_list = "/global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/files.txt"
# print("Using files in " + file_list)
print("success!")
# Out:
# Using files in /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/files.txt

# %% [markdown]
# In this notebook we use Keras and XGBoost to distinguish between hits from conversion electrons and hits from other particles

# %%
import uproot 
import awkward as ak
import numpy as np
import matplotlib.pyplot as plt
import datetime
import tensorflow as tf
from pathlib import Path
import os
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Dropout, Activation, ReLU
from tensorflow.keras.optimizers import SGD
import tensorflow.keras.layers
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, roc_auc_score
from xgboost import XGBClassifier
# Out:
# 2023-04-05 12:55:17.590078: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
rm -rf ./logs/

# %% [markdown]
# In our problem we have a different number of signal and background entries in our input dataset. There are several techniques avaialable for _unbalanced_ datasets. Here we are using the most naive one, which is just using $\min(N_{sig}, N_{bkg})$ events. Then, we divide our input into the _training_, _validation_, and _test_ datasets.  Note that the datasets must be pruned to the nearest multiple of the batch size, otherwise the gradient calculation fails.

# %%
input_dataset = np.empty
temp = np.empty
signal = np.empty
backgnd = np.empty
files = open(file_list, 'r')
for filename in files:
    print("Processing file " + filename)
    # pathToFile = Path(filepath1 + filename)
    # print (filepath1+filename)
    # print(pathToFile)
    # file = uproot.open(pathToFile)
    with uproot.open(filename) as file:
        trkana = file[treename]["trkana"].arrays(filter_name="/de|detsh|detshmc|demc/i")
        trkana = trkana[(trkana['de.goodfit']==1)&(trkana['de.status']>0)&(trkana['demc.proc']==167)]
        hstate = ak.concatenate(trkana['detsh.state']).to_numpy()
        udoca = ak.concatenate(trkana['detsh.udoca']).to_numpy()
        udoca = np.absolute(udoca)
        cdrift = ak.concatenate(trkana['detsh.cdrift']).to_numpy()
        rdrift = ak.concatenate(trkana['detsh.rdrift']).to_numpy()
        tottdrift = ak.concatenate(trkana['detsh.tottdrift']).to_numpy()
        edep = ak.concatenate(trkana['detsh.edep']).to_numpy()
        sint = ak.concatenate(trkana['detsh.wdot']).to_numpy()
        sint = np.sqrt(1.0-sint*sint)
        plen = 6.25-rdrift*rdrift
        pmin = np.repeat(0.25,plen.shape[0])
        plen = np.sqrt(np.maximum(plen,pmin))
        edep = edep*sint/plen
        udocasig = ak.concatenate(trkana['detsh.udocavar']).to_numpy()
        udocasig = np.sqrt(udocasig)
        wdist = ak.concatenate(trkana['detsh.wdist']).to_numpy()
        uupos = ak.concatenate(trkana['detsh.uupos']).to_numpy()
        du = wdist-uupos
        du = np.absolute(du)
        rho = np.square(ak.concatenate(trkana['detsh.poca.fCoordinates.fX']).to_numpy())
        rho = np.add(rho,np.square(ak.concatenate(trkana['detsh.poca.fCoordinates.fY']).to_numpy()))
        rho = np.sqrt(rho)
        print("Processed file " + filename + " with %s hits"%hstate.shape[0])
        temp = np.vstack((udoca, cdrift, udocasig, tottdrift, edep, du, rho)).T
        if input_dataset is np.empty:
            input_dataset = temp
        else:
            input_dataset = np.concatenate((input_dataset, temp))
        mcrel = []
        for i, this_dt in enumerate(trkana['detsh.state']):
            mcrel.extend(trkana['detshmc.rel._rel'][i][:len(this_dt)])
        mcrel = np.array(mcrel)
        rand = np.random.random_sample([mcrel.shape[0]])
        sig = (hstate>=-2) & (rand<0.05) & (mcrel==0) & (udoca < 50.0) & (du < 3000.0)
        bkg = (hstate>=-2) & (mcrel==-1) & (udoca < 50.0) & ( du < 3000.0)
        if signal is np.empty:
            signal = sig
            backgnd = bkg
        else:
            signal = np.concatenate((signal,sig))
            backgnd = np.concatenate((backgnd,bkg))
nhits=len(input_dataset)
nsignal=signal.sum()
nbackgnd=backgnd.sum()
print("Total dataset %s hits, %s signal and %s background"%(nhits,nsignal,nbackgnd))
# Out:
# Processing file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000005.root
#
# Processed file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000005.root
#  with 500075 hits
# Processing file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000026.root
#
# Processed file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000026.root
#  with 490578 hits
# Processing file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000065.root
#
# Processed file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000065.root
#  with 498274 hits
# Processing file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000104.root
#
# Processed file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000104.root
#  with 499791 hits
# Processing file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000135.root
#
# Processed file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000135.root
#  with 496400 hits
# Processing file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000170.root
#
# Processed file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000170.root
#  with 492009 hits
# Processing file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000202.root
#
# Processed file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000202.root
#  with 494827 hits
# Processing file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000221.root
#
# Processed file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000221.root
#  with 502681 hits
# Processing file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000264.root
#
# Processed file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000264.root
#  with 496195 hits
# Processing file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000300.root
#
# Processed file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000300.root
#  with 498757 hits
# Processing file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000334.root
#
# Processed file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000334.root
#  with 501304 hits
# Processing file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000375.root
#
# Processed file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000375.root
#  with 498783 hits
# Processing file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000408.root
#
# Processed file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000408.root
#  with 497568 hits
# Processing file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000444.root
#
# Processed file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000444.root
#  with 495857 hits
# Processing file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000485.root
#
# Processed file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000485.root
#  with 494293 hits
# Processing file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000513.root
#
# Processed file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000513.root
#  with 498698 hits
# Processing file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000556.root
#
# Processed file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000556.root
#  with 499691 hits
# Processing file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000584.root
#
# Processed file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000584.root
#  with 500868 hits
# Processing file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000622.root
#
# Processed file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000622.root
#  with 492834 hits
# Processing file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000667.root
#
# Processed file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000667.root
#  with 493784 hits
# Processing file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000711.root
#
# Processed file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000711.root
#  with 502909 hits
# Processing file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000763.root
#
# Processed file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000763.root
#  with 494777 hits
# Processing file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000784.root
#
# Processed file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000784.root
#  with 502604 hits
# Processing file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000823.root
#
# Processed file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000823.root
#  with 497044 hits
# Processing file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000864.root
#
# Processed file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000864.root
#  with 498897 hits
# Processing file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000893.root
#
# Processed file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000893.root
#  with 494287 hits
# Processing file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000924.root
#
# Processed file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000924.root
#  with 496217 hits
# Processing file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000969.root
#
# Processed file /global/cfs/cdirs/m3712/Mu2e/TrkAna/60358177/nts.brownd.TTKKSeed.TTTAT.001210_00000969.root
#  with 345147 hits
# Total dataset 13775149 hits, 670153 signal and 58741 background

# %%
min_len = min(len(input_dataset[signal]), len(input_dataset[backgnd]))
bsize=32
# I need to double the batch_size when truncating as we divide the sample in half later for training
tsize=2*bsize
min_len = min_len - min_len%tsize
print("Training on %s matched hits"%min_len)
signal_dataset = input_dataset[signal][:min_len]
bkg_dataset = input_dataset[backgnd][:min_len]

balanced_input = np.concatenate((signal_dataset, bkg_dataset))
y_balanced_input = np.concatenate((np.ones(signal_dataset.shape[0]), np.zeros(bkg_dataset.shape[0])))

n_variables = balanced_input.shape[1]

x_ce_train, x_ce_test, y_ce_train, y_ce_test = train_test_split(balanced_input, y_balanced_input, test_size=0.5, random_state=42)
x_ce_test, x_ce_valid, y_ce_test, y_ce_valid = train_test_split(x_ce_test, y_ce_test, test_size=0.5, random_state=42)
# Out:
# Training on 58688 matched hits

# %%
udoca_sig = []
tottdrift_sig = []
cdrift_sig = []
udocasig_sig = []
edep_sig = []
du_sig = []
rho_sig = []

for i in range(signal_dataset.shape[0]):
    udoca_sig.append(signal_dataset[i][0])
    
for i in range(signal_dataset.shape[0]):
    cdrift_sig.append(signal_dataset[i][1])
    
for i in range(signal_dataset.shape[0]):
    udocasig_sig.append(signal_dataset[i][2])

for i in range(signal_dataset.shape[0]):
    tottdrift_sig.append(signal_dataset[i][3])
    
for i in range(signal_dataset.shape[0]):
    edep_sig.append(signal_dataset[i][4])

for i in range(signal_dataset.shape[0]):
    du_sig.append(signal_dataset[i][5])

for i in range(signal_dataset.shape[0]):
    rho_sig.append(signal_dataset[i][6])

# %%
udoca_back = []
tottdrift_back = []
cdrift_back = []
udocasig_back = []
edep_back = []
du_back = []
rho_back = []
    
for i in range(bkg_dataset.shape[0]):
    udoca_back.append(bkg_dataset[i][0])
    
for i in range(bkg_dataset.shape[0]):
    cdrift_back.append(bkg_dataset[i][1])
    
for i in range(bkg_dataset.shape[0]):
    udocasig_back.append(bkg_dataset[i][2])

for i in range(bkg_dataset.shape[0]):
    tottdrift_back.append(bkg_dataset[i][3])

for i in range(bkg_dataset.shape[0]):
    edep_back.append(bkg_dataset[i][4])
    
for i in range(bkg_dataset.shape[0]):
    du_back.append(bkg_dataset[i][5])
    
for i in range(bkg_dataset.shape[0]):
    rho_back.append(bkg_dataset[i][6])

# %%
plt.hist(udoca_sig,label="Unbiased DOCA Signal", bins=100,range=(0,15))
plt.hist(udoca_back,label="Unbiased DOCA Background", histtype='step', bins=100,range=(0,15))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(cdrift_sig,label="Drift Radius Signal", bins=50,range=(-3.0,5.0))
plt.hist(cdrift_back,label="Drift Radius Background", histtype='step', bins=50, range=(-3.0,5.0))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(udocasig_sig,label="DOCA Variance Signal", bins=50,range=(0,5))
plt.hist(udocasig_back,label="DOCA Variance Background", histtype='step', bins=50,range=(0,5))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(tottdrift_sig,label="Time-Over-Threshold Drift Time Signal", bins=50, range=(0,40))
plt.hist(tottdrift_back,label="Time-Over-Threshold Drift Time Background", histtype='step', bins=50,range=(0,40))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(edep_sig,label="Energy Deposition Signal",bins=50,range=(0,0.007))
plt.hist(edep_back,label="Energy Deposition Background", histtype='step', bins=50, range=(0,0.007))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(du_sig,label="WDist - Unbiased U Position Difference Signal", bins=50, range=(0,800))
plt.hist(du_back,label="WDist - Unbiased U Position Difference Background", histtype='step', bins=50, range=(0,800))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(rho_sig,label="Rho Signal", bins=50, range=(350,700))
plt.hist(rho_back,label="Rho Background", histtype='step', bins=50, range=(350,700))
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Then, we concatenate each hit variables into a single, large numpy array. These arrays are then stacked in a single bi-dimensional array with `np.vstack`, which will be our input dataset used for the training of the machine learning algorithms.

# %% [markdown]
# Here we then assign a label to each hit as _signal_ or _background_, depending on the Monte Carlo truth information. Since the dimension of  `detshmc.rel._rel` is not guaranteed to be the same as the dimension of `detsh` we need to loop over all the entries.

# %% [markdown]
# ## Create and train a multi-layer perceptron

# %% [markdown]
# Here we create a _multi-layer perceptron_ (MLP) model which consists of 3 fully-connected (or _dense_) layers, each one followed by a _dropout_ layer, which helps to avoid overfitting. The model is trained using the [Adam](https://arxiv.org/abs/1412.6980) optimizer and trained for 50 epochs or until the validation loss doesn't improve for 5 epochs (`early_stop`). The model we save must be created first, with an explicit input layer with explicit batch_size, otherwise it can't be parsed by the TMVA::SOFIE parser we use to generate a C++ inference function downstream.

# %% [markdown]
# The output model must have batch_size=1, otherwise the SOFIE inference function will assume that many input variables at a time.  Training (gradient calculation) however is much more efficient with a larger batch size, so we construct a separate model for that.  After training and before saving, we'll copy the weights (which don't depend on batch_size) from the trained model to the output model.  This should be unnecessary in the next verison of ROOT.
#
# We should initialize the model by reading a previous iteration. TODO

# %%
lay0=Input(shape=(n_variables,),batch_size=1)
lay1=Dense(2*n_variables, activation='relu')(lay0)
lay2=Dense(2*n_variables, activation='relu')(lay1)
lay3=Dense(2*n_variables, activation='relu')(lay2)
lay4=Dense(1,activation='sigmoid')(lay3)
output_model=Model(inputs=lay0,outputs=lay4)

opt = Adam(learning_rate=1e-3)
input=Input(shape=(n_variables,),batch_size=bsize)
x=Dense(2*n_variables, activation='relu')(input)
x=Dense(2*n_variables, activation='relu')(x)
x=Dense(2*n_variables, activation='relu')(x)
output=Dense(1,activation='sigmoid')(x)
model_ce=Model(inputs=input,outputs=output)
model_ce.compile(loss='binary_crossentropy',metrics='accuracy',optimizer=opt)
early_stop = EarlyStopping(monitor='val_loss', patience=20, min_delta=1e-5, restore_best_weights=True)
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tensorflow.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
history_ce = model_ce.fit(x_ce_train, y_ce_train,
                          batch_size=bsize,
                          epochs=200,
                          verbose=1,
                          validation_data=(x_ce_valid, y_ce_valid),
                          callbacks=[early_stop, tensorboard_callback]
                         )
# Out:
# 2023-04-05 13:01:13.892599: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/200
# 1834/1834 [==============================] - 3s 1ms/step - loss: 0.4851 - accuracy: 0.8484 - val_loss: 0.3090 - val_accuracy: 0.8874
# Epoch 2/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.3149 - accuracy: 0.8801 - val_loss: 0.2920 - val_accuracy: 0.8892
# Epoch 3/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.3063 - accuracy: 0.8831 - val_loss: 0.2897 - val_accuracy: 0.8925
# Epoch 4/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.2967 - accuracy: 0.8870 - val_loss: 0.2923 - val_accuracy: 0.8854
# Epoch 5/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.2890 - accuracy: 0.8883 - val_loss: 0.2841 - val_accuracy: 0.8881
# Epoch 6/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.2862 - accuracy: 0.8885 - val_loss: 0.2803 - val_accuracy: 0.8928
# Epoch 7/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.2835 - accuracy: 0.8902 - val_loss: 0.2826 - val_accuracy: 0.8900
# Epoch 8/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.2824 - accuracy: 0.8900 - val_loss: 0.2835 - val_accuracy: 0.8906
# Epoch 9/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.2810 - accuracy: 0.8914 - val_loss: 0.2846 - val_accuracy: 0.8885
# Epoch 10/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.2810 - accuracy: 0.8903 - val_loss: 0.2814 - val_accuracy: 0.8917
# Epoch 11/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.2788 - accuracy: 0.8921 - val_loss: 0.2836 - val_accuracy: 0.8894
# Epoch 12/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.2787 - accuracy: 0.8926 - val_loss: 0.2760 - val_accuracy: 0.8935
# Epoch 13/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.2783 - accuracy: 0.8918 - val_loss: 0.2724 - val_accuracy: 0.8935
# Epoch 14/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.2776 - accuracy: 0.8922 - val_loss: 0.2812 - val_accuracy: 0.8925
# Epoch 15/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.2785 - accuracy: 0.8920 - val_loss: 0.2847 - val_accuracy: 0.8899
# Epoch 16/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.2775 - accuracy: 0.8927 - val_loss: 0.2732 - val_accuracy: 0.8947
# Epoch 17/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.2757 - accuracy: 0.8939 - val_loss: 0.2847 - val_accuracy: 0.8907
# Epoch 18/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.2755 - accuracy: 0.8925 - val_loss: 0.2705 - val_accuracy: 0.8950
# Epoch 19/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.2748 - accuracy: 0.8926 - val_loss: 0.2816 - val_accuracy: 0.8907
# Epoch 20/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.2749 - accuracy: 0.8933 - val_loss: 0.2807 - val_accuracy: 0.8908
# Epoch 21/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.2743 - accuracy: 0.8944 - val_loss: 0.2717 - val_accuracy: 0.8948
# Epoch 22/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.2733 - accuracy: 0.8940 - val_loss: 0.2737 - val_accuracy: 0.8941
# Epoch 23/200
# 1834/1834 [==============================] - 3s 1ms/step - loss: 0.2739 - accuracy: 0.8930 - val_loss: 0.2751 - val_accuracy: 0.8921
# Epoch 24/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.2733 - accuracy: 0.8937 - val_loss: 0.2736 - val_accuracy: 0.8939
# Epoch 25/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.
200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.1951 - accuracy: 0.9275 - val_loss: 0.2004 - val_accuracy: 0.9252
# Epoch 177/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.1953 - accuracy: 0.9274 - val_loss: 0.1915 - val_accuracy: 0.9287
# Epoch 178/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.1953 - accuracy: 0.9268 - val_loss: 0.1988 - val_accuracy: 0.9265
# Epoch 179/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.1943 - accuracy: 0.9277 - val_loss: 0.1957 - val_accuracy: 0.9279
# Epoch 180/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.1947 - accuracy: 0.9276 - val_loss: 0.1989 - val_accuracy: 0.9266
# Epoch 181/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.1942 - accuracy: 0.9272 - val_loss: 0.2021 - val_accuracy: 0.9250
# Epoch 182/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.1958 - accuracy: 0.9271 - val_loss: 0.1932 - val_accuracy: 0.9282
# Epoch 183/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.1939 - accuracy: 0.9278 - val_loss: 0.1936 - val_accuracy: 0.9284
# Epoch 184/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.1945 - accuracy: 0.9280 - val_loss: 0.2010 - val_accuracy: 0.9264
# Epoch 185/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.1948 - accuracy: 0.9274 - val_loss: 0.1931 - val_accuracy: 0.9296
# Epoch 186/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.1948 - accuracy: 0.9281 - val_loss: 0.1996 - val_accuracy: 0.9280
# Epoch 187/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.1946 - accuracy: 0.9273 - val_loss: 0.2061 - val_accuracy: 0.9259
# Epoch 188/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.1960 - accuracy: 0.9272 - val_loss: 0.1970 - val_accuracy: 0.9280
# Epoch 189/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.1955 - accuracy: 0.9270 - val_loss: 0.1948 - val_accuracy: 0.9273
# Epoch 190/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.1945 - accuracy: 0.9278 - val_loss: 0.1970 - val_accuracy: 0.9279
# Epoch 191/200
# 1834/1834 [==============================] - 3s 1ms/step - loss: 0.1942 - accuracy: 0.9278 - val_loss: 0.1951 - val_accuracy: 0.9279
# Epoch 192/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.1940 - accuracy: 0.9266 - val_loss: 0.1946 - val_accuracy: 0.9281
# Epoch 193/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.1947 - accuracy: 0.9274 - val_loss: 0.2011 - val_accuracy: 0.9263
# Epoch 194/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.1940 - accuracy: 0.9273 - val_loss: 0.2068 - val_accuracy: 0.9254
# Epoch 195/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.1944 - accuracy: 0.9279 - val_loss: 0.1979 - val_accuracy: 0.9292
# Epoch 196/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.1942 - accuracy: 0.9277 - val_loss: 0.2179 - val_accuracy: 0.9184
# Epoch 197/200
# 1834/1834 [==============================] - 2s 1ms/step - loss: 0.1937 - accuracy: 0.9279 - val_loss: 0.2055 - val_accuracy: 0.9247

# %%
plt.plot(history_ce.history['val_loss'],label="val loss")
plt.plot(history_ce.history['loss'],label="loss")
plt.legend()

# %load_ext tensorboard
#rm -rf ./logs/
# %tensorboard --logdir logs/fit
# Out:
# ERROR: Could not find `tensorboard`. Please ensure that your PATH
# contains an executable `tensorboard` program, or explicitly specify
# the path to a TensorBoard binary by setting the `TENSORBOARD_BINARY`
# environment variable.

# %% [markdown]
# ## Create and train a Boosted Decision Tree
# Here, instead of using a MLP, we use a [_Gradient Boosted Decision Tree_](https://xgboost.readthedocs.io/en/stable/) (BDT) to distinguish between signal (true CE hits) and background (fake CE hits). We use the defualt hyperparameters.

# %%
model_xgboost = XGBClassifier()
model_xgboost.fit(x_ce_train, y_ce_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %% [markdown]
# Here we can finally apply our two models (the MLP and the BDT) to our test datasets and create the corresponding ROC curves.

# %%
#prediction_ce = model_ce.predict(x_ce_test).ravel()
prediction_ce = model_ce.predict(x_ce_test)
fpr_ce, tpr_ce, th_ce = roc_curve(y_ce_test,  prediction_ce)
auc_ce = roc_auc_score(y_ce_test, prediction_ce)
# Out:
# 917/917 [==============================] - 1s 712us/step

# %%
prediction_xgboost = model_xgboost.predict_proba(x_ce_test)[:,1]
fpr_xgboost, tpr_xgboost, th_xgboost = roc_curve(y_ce_test,  prediction_xgboost)
auc_xgboost = roc_auc_score(y_ce_test, prediction_xgboost)

# %% [markdown]
# The plot of the ROC curves clearly shows that the BDT outperforms the MLP. In principle, however, it should be possible to improve the MLP performances by optimizing the hyperparameters (learning rate, hidden layers, activation functions, etc.).

# %%
fig, ax = plt.subplots(1,1)
ax.plot(tpr_ce,1-fpr_ce,label=f'MLP AUC: {auc_ce:.4f}')
ax.plot(tpr_xgboost,1-fpr_xgboost,label=f'BDT AUC: {auc_xgboost:.4f}')

ax.legend()
ax.set_aspect("equal")
ax.set_xlabel("Signal efficiency")
ax.set_ylabel("Background rejection")
ax.set_xlim(0.8,1.05)
ax.set_ylim(0.8,1.05)

fig.savefig("training_plots/TrainBkg" + suffix + ".pdf")

# %% [markdown]
# Now we save our model in HDF5 format.  This can be used as input to the SOFIE parser.  Note that the kernel must be restarted when saving this file, as re-running individual cells increments the layer numbers in the hdf5 file, causing the SOFIE parser to fail.  This causes the spurious tensorflow warning about the model not having been built.

# %%
output_model.set_weights(model_ce.get_weights())
output_model.summary()
output_model.save("models/TrainBkg" + suffix + ".h5")
model_ce.save("models/TrainBkgOriginal" + suffix + ".h5")
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(1, 7)]                  0
#
#  dense (Dense)               (1, 14)                   112
#
#  dense_1 (Dense)             (1, 14)                   210
#
#  dense_2 (Dense)             (1, 14)                   210
#
#  dense_3 (Dense)             (1, 1)                    15
#
# =================================================================
# Total params: 547
# Trainable params: 547
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# Now we save our model in HDF5 format.  This can be used as input to the SOFIE parser.  Note that the kernel must be restarted when saving this file, as re-running individual cells increments the layer numbers in the hdf5 file, causing the SOFIE parser to fail.  This causes the spurious tensorflow warning about the model not having been built.
