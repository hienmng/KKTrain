# %% [markdown]
# # Training File for Final Dataset

# %% [markdown]
# This is a training file for the Final dataset (cluster number 65717793) located at "/global/cfs/cdirs/m3712/Mu2e/TrkAna/65717793". Running the following cells will call and run TrainBkg.ipynb. The AUC curve generated will be saved as "TrainBkgFinal.pdf" in the "training_plots" directory, and the .h5 file training model generated will be saved as "TrainBkgFinal.h5" in the "models" file

# %%
suffix = "Final"
treename = "TAKK"
#file_list = "/global/cfs/cdirs/m3712/Mu2e/TrkAna/65717793/files.txt"
file_list = "/Users/brownd/data/65717793/files.txt"
print("Using files in " + file_list)

# %run ./TrainBkg.ipynb
# Out:
# Using files in /Users/brownd/data/65717793/files.txt
# Loaded TrainBkg
# 2023-04-18 17:18:30.087651: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Processing file /Users/brownd/data/65717793/nts.brownd.KKDrift.KKDP.001210_00000000.root
#
# Processed file /Users/brownd/data/65717793/nts.brownd.KKDrift.KKDP.001210_00000000.root
#  with 578211 hits
# Processing file /Users/brownd/data/65717793/nts.brownd.KKDrift.KKDP.001210_00000010.root
#
# Processed file /Users/brownd/data/65717793/nts.brownd.KKDrift.KKDP.001210_00000010.root
#  with 581577 hits
# Processing file /Users/brownd/data/65717793/nts.brownd.KKDrift.KKDP.001210_00000020.root
#
# Processed file /Users/brownd/data/65717793/nts.brownd.KKDrift.KKDP.001210_00000020.root
#  with 581677 hits
# Processing file /Users/brownd/data/65717793/nts.brownd.KKDrift.KKDP.001210_00000030.root
#
# Processed file /Users/brownd/data/65717793/nts.brownd.KKDrift.KKDP.001210_00000030.root
#  with 577914 hits
# Processing file /Users/brownd/data/65717793/nts.brownd.KKDrift.KKDP.001210_00000040.root
#
# Processed file /Users/brownd/data/65717793/nts.brownd.KKDrift.KKDP.001210_00000040.root
#  with 585085 hits
# Processing file /Users/brownd/data/65717793/nts.brownd.KKDrift.KKDP.001210_00000050.root
#
# Processed file /Users/brownd/data/65717793/nts.brownd.KKDrift.KKDP.001210_00000050.root
#  with 580534 hits
# Processing file /Users/brownd/data/65717793/nts.brownd.KKDrift.KKDP.001210_00000060.root
#
# Processed file /Users/brownd/data/65717793/nts.brownd.KKDrift.KKDP.001210_00000060.root
#  with 577431 hits
# Processing file /Users/brownd/data/65717793/nts.brownd.KKDrift.KKDP.001210_00000070.root
#
# Processed file /Users/brownd/data/65717793/nts.brownd.KKDrift.KKDP.001210_00000070.root
#  with 586935 hits
# Processing file /Users/brownd/data/65717793/nts.brownd.KKDrift.KKDP.001210_00000080.root
#
# Processed file /Users/brownd/data/65717793/nts.brownd.KKDrift.KKDP.001210_00000080.root
#  with 590124 hits
# Processing file /Users/brownd/data/65717793/nts.brownd.KKDrift.KKDP.001210_00000090.root
#
# Processed file /Users/brownd/data/65717793/nts.brownd.KKDrift.KKDP.001210_00000090.root
#  with 580575 hits
# Total dataset 5820063 hits, 276427 signal and 121059 background
# Training on 121024 matched hits
# Loading model from file models/TrainBkgFinal.h5
# Epoch 1/200
# 2023-04-18 17:23:43.633826: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 3782/3782 [==============================] - 5s 1ms/step - loss: 0.0651 - accuracy: 0.9797 - val_loss: 0.0656 - val_accuracy: 0.9785
# Epoch 2/200
# 3782/3782 [==============================] - 4s 1ms/step - loss: 0.0648 - accuracy: 0.9798 - val_loss: 0.0655 - val_accuracy: 0.9788
# Epoch 3/200
# 3782/3782 [==============================] - 4s 1ms/step - loss: 0.0650 - accuracy: 0.9797 - val_loss: 0.0751 - val_accuracy: 0.9758
# Epoch 4/200
# 3782/3782 [==============================] - 4s 1ms/step - loss: 0.0646 - accuracy: 0.9797 - val_loss: 0.0639 - val_accuracy: 0.9794
# Epoch 5/200
# 3782/3782 [==============================] - 4s 1ms/step - loss: 0.0646 - accuracy: 0.9797 - val_loss: 0.0643 - val_accuracy: 0.9793
# Epoch 6/200
# 3782/3782 [==============================] - 4s 1ms/step - loss: 0.0646 - accuracy: 0.9797 - val_loss: 0.0671 - val_accuracy: 0.9788
# Epoch 7/200
# 3782/3782 [==============================] - 4s 1ms/step - loss: 0.0642 - accuracy: 0.9800 - val_loss: 0.0666 - val_accuracy: 0.9786
# Epoch 8/200
# 3782/3782 [==============================] - 4s 1ms/step - loss: 0.0644 - accuracy: 0.9798 - val_loss: 0.0684 - val_accuracy: 0.9781
# Epoch 9/200
# 3782/3782 [==============================] - 4s 1ms/step - loss: 0.0642 - accuracy: 0.9801 - val_loss: 0.0702 - val_accuracy: 0.9766
# Epoch 10/200
# 3782/3782 [==============================] - 4s 1ms/step - loss: 0.0644 - accuracy: 0.9798 - val_loss: 0.0652 - val_accuracy: 0.9796
# Epoch 11/200
# 3782/3782 [==============================] - 4s 1ms/step - loss: 0.0642 - accuracy: 0.9800 - val_loss: 0.0662 - val_accuracy: 0.9791
# Epoch 12/200
# 3782/3782 [==============================] - 4s 1ms/step - loss: 0.0644 - accuracy: 0.9797 - val_loss: 0.0733 - val_accuracy: 0.9759
# Epoch 13/200
# 3782/3782 [==============================] - 4s 1ms/step - loss: 0.0640 - accuracy: 0.9802 - val_loss: 0.0678 - val_accuracy: 0.9785
# Epoch 14/200
# 3782/3782 [==============================] - 4s 1ms/step - loss: 0.0642 - accuracy: 0.9800 - val_loss: 0.0699 - val_accuracy: 0.9784
# Epoch 15/200
# 3782/3782 [==============================] - 4s 1ms/step - loss: 0.0643 - accuracy: 0.9801 - val_loss: 0.0675 - val_accuracy: 0.9779
# Epoch 16/200
# 3782/3782 [==============================] - 4s 1ms/step - loss: 0.0640 - accuracy: 0.9799 - val_loss: 0.0649 - val_accuracy: 0.9794
# Epoch 17/200
# 3782/3782 [==============================] - 4s 1ms/step - loss: 0.0644 - accuracy: 0.9799 - val_loss: 0.0662 - val_accuracy: 0.9783
# Epoch 18/200
# 3782/3782 [==============================] - 4s 1ms/step - loss: 0.0641 - accuracy: 0.9799 - val_loss: 0.0669 - val_accuracy: 0.9787
# Epoch 19/200
# 3782/3782 [==============================] - 4s 1ms/step - loss: 0.0639 - accuracy: 0.9800 - val_loss: 0.0687 - val_accuracy: 0.9777
# Epoch 20/200
# 3782/3782 [==============================] - 4s 1ms/step - loss: 0.0643 - accuracy: 0.9800 - val_loss: 0.0695 - val_accuracy: 0.9777
# Epoch 21/200
# 3782/3782 [==============================] - 4s 1ms/step - loss: 0.0636 - accuracy: 0.9802 - val_loss: 0.0658 - val_accuracy: 0.9790
# Epoch 22/200
# 3782/3782 [==============================] - 4s 1ms/step - loss: 0.0641 - accuracy: 0.9800 - val_loss: 0.0655 - val_accuracy: 0.9790
# Epoch 23/200
# 3782/3782 [==============================] - 4s 1ms/step - loss: 0.0638 - accuracy: 0.9799 - val_loss: 0.0650 - val_accuracy: 0.9791
# Epoch 24/200
# 3782/3782 [==============================] - 4s 1ms/step - loss: 0.0639 - accuracy: 0.9799 - val_loss: 0.0648 - val_accuracy: 0.9793
# ERROR: Could not find `tensorboard`. Please ensure that your PATH
# contains an executable `tensorboard` program, or explicitly specify
# the path to a TensorBoard binary by setting the `TENSORBOARD_BINARY`
# environment variable.
# [17:25:25] WARNING: /var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_44tbtwf8c1/croots/recipe/xgboost-split_1659548960882/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 1891/1891 [==============================] - 1s 539us/step
# model saved to models/TrainBkgFinal.h5
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(32, 7)]                 0
#
#  dense (Dense)               (32, 14)                  112
#
#  dense_1 (Dense)             (32, 14)                  210
#
#  dense_2 (Dense)             (32, 14)                  210
#
#  dense_3 (Dense)             (32, 1)                   15
#
# =================================================================
# Total params: 547
# Trainable params: 547
# Non-trainable params: 0
# _________________________________________________________________
